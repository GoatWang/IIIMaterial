# %%
import subprocess
import os
import re

# %% [markdown]
# # Practice

# %%
dirs = [d for d in os.listdir('..') if bool(re.match('\d+\_.+?', d))]
dirs = sorted(dirs)
for d in dirs[:]: 
    for f in os.listdir(os.path.join('..', d)):
        if f.startswith('main') and f.endswith('.ipynb'):
            readfile_path = os.path.join("..", d, f)
            writefile_path = os.path.join("..", d, f.replace("main", "practice"))
            print(readfile_path)
            print(writefile_path)
            readfile = open(readfile_path, 'r', encoding='utf8')
            writefile = open(writefile_path, 'w', encoding='utf8')
            starts_equal = False
            starts_all = False
            for line in readfile:
                if "#==============your works ends================#" in line:
                    starts_equal = False
                if "#!==============your works ends================!#" in line:
                    starts_all = False
                if starts_equal and "=" in line:
                    line = line.split("=")[0] + "=" + line[-5:]
                if starts_all:
                    line = line[:5] + line[-5:]
                if "#=============your works starts===============#" in line:
                    starts_equal = True
                if "#!=============your works starts===============!#" in line:
                    starts_all = True

                writefile.write(line)
                
            readfile.close()
            writefile.close()
# Out:
# ..\00_EnvironmentInstallation\main00.ipynb
# ..\00_EnvironmentInstallation\practice00.ipynb
# ..\01_MLIntroduction\main01.ipynb
# ..\01_MLIntroduction\practice01.ipynb
# ..\02_PreProcessing\main02.ipynb
# ..\02_PreProcessing\practice02.ipynb
# ..\03_ClusteringTheory\main03.ipynb
# ..\03_ClusteringTheory\practice03.ipynb
# ..\04_ClusteringPracticeWord2Vec\main04.ipynb
# ..\04_ClusteringPracticeWord2Vec\practice04.ipynb
# ..\05_Classification\main05.ipynb
# ..\05_Classification\practice05.ipynb
# ..\06_XgbCV\main06.ipynb
# ..\06_XgbCV\practice06.ipynb
# ..\07_RealEstatePractice\main07.ipynb
# ..\07_RealEstatePractice\practice07.ipynb
# ..\08_InformationRetreival\main08.ipynb
# ..\08_InformationRetreival\practice08.ipynb
# ..\09_RecommendationSystem\main09.ipynb
# ..\09_RecommendationSystem\practice09.ipynb

# %% [markdown]
# # Latex

# %%
working_dirs = [d for d in os.listdir("..") if re.findall('\d{2}', d)]
for working_dir in working_dirs[5:6]:
    print("working_dir", working_dir)

    filename = [f for f in os.listdir(os.path.join("..", working_dir)) if f.startswith('practice')][0]
    filepath = os.path.join("..", working_dir, filename)
    calls = ["jupyter", "nbconvert", "--to", "latex", filepath]
    p = subprocess.Popen(" ".join(calls), stdout=subprocess.PIPE, stderr=subprocess.PIPE, shell=True)
    out, err = p.communicate()
    print("out, err")
    print(out.decode(), err.decode())
    print("=================")
    
    tex_read_filepath = filepath.replace('ipynb', 'tex')
    tex_write_filepath = tex_read_filepath.replace('.tex', '_mod.tex')

    tex_read_file = open(tex_read_filepath, 'r', encoding='utf8')
    tex_write_file = open(tex_write_filepath, 'w', encoding='utf8')
    for line in tex_read_file:
        if "documentclass" in line:
            tex_write_file.write(line)
            tex_write_file.write("    \\usepackage{fontspec}\n")
            tex_write_file.write("    \\usepackage{xeCJK}\n")
            tex_write_file.write("    \\setCJKmainfont{微軟正黑體}\n")
        else:
            static_dir = filename.replace('.ipynb', '') + "_files"
            if static_dir in line:
                static_file = re.findall('\{' + static_dir + '.+?\}', line)[0]
                static_file_new = "{../" + working_dir + "/" + static_file[1:]
                line = line.replace(static_file, static_file_new) 
            if "imgs" in line:
                print("line ==>", line)
                print("=============================")
                line = line.replace("./imgs", "../" + working_dir + "/" + "imgs")
            if "\\title" in line:
                to_be_replace = re.findall("\{.+?\}", line)[0]
                line = line.replace(to_be_replace, "{" + working_dir.replace("_", "") + "}")
            if not ("users" in line.lower() and "administrator" in line.lower()) and not "gif" in line.lower() and not ("user" in line and "appdata" in line.lower()):
                tex_write_file.write(line)

    tex_read_file.close()
    tex_write_file.close()
    
    
    calls = ["xelatex", tex_write_filepath]
    p = subprocess.Popen(" ".join(calls), stdout=subprocess.PIPE, stderr=subprocess.PIPE, shell=True)
    out, err = p.communicate()
    
    print("out, err")
    print(out.decode(), err.decode())
    print("=================")
    print("=================")
    print("=================")
    print("=================")
    print("=================")
# Out:
# working_dir 05_Classification
# out, err
#  [NbConvertApp] Converting notebook ..\05_Classification\practice05.ipynb to latex
# [NbConvertApp] Support files will be in practice05_files\
# [NbConvertApp] Making directory ..\05_Classification\practice05_files
# [NbConvertApp] Making directory ..\05_Classification\practice05_files
# [NbConvertApp] Making directory ..\05_Classification\practice05_files
# [NbConvertApp] Making directory ..\05_Classification\practice05_files
# [NbConvertApp] Making directory ..\05_Classification\practice05_files
# [NbConvertApp] Making directory ..\05_Classification\practice05_files
# [NbConvertApp] Making directory ..\05_Classification\practice05_files
# [NbConvertApp] Making directory ..\05_Classification\practice05_files
# [NbConvertApp] Making directory ..\05_Classification\practice05_files
# [NbConvertApp] Making directory ..\05_Classification\practice05_files
# [NbConvertApp] Making directory ..\05_Classification\practice05_files
# [NbConvertApp] Making directory ..\05_Classification\practice05_files
# [NbConvertApp] Making directory ..\05_Classification\practice05_files
# [NbConvertApp] Making directory ..\05_Classification\practice05_files
# [NbConvertApp] Making directory ..\05_Classification\practice05_files
# [NbConvertApp] Making directory ..\05_Classification\practice05_files
# [NbConvertApp] Making directory ..\05_Classification\practice05_files
# [NbConvertApp] Making directory ..\05_Classification\practice05_files
# [NbConvertApp] Making directory ..\05_Classification\practice05_files
# [NbConvertApp] Making directory ..\05_Classification\practice05_files
# [NbConvertApp] Making directory ..\05_Classification\practice05_files
# [NbConvertApp] Making directory ..\05_Classification\practice05_files
# [NbConvertApp] Making directory ..\05_Classification\practice05_files
# [NbConvertApp] Making directory ..\05_Classification\practice05_files
# [NbConvertApp] Writing 105602 bytes to ..\05_Classification\practice05.tex
#
# =================
# line ==> \includegraphics{./imgs/catImgs.JPG}
#
# =============================
# line ==> \includegraphics{./imgs/KNN.jpg}
#
# =============================
# line ==>     可以整理成=\textgreater{} \includegraphics{./imgs/basian_table.PNG}
#
# =============================
# line ==> \includegraphics{./imgs/regression.png}
#
# =============================
# line ==> \includegraphics{./imgs/logistic_reg.png}
#
# =============================
# line ==> \includegraphics{./imgs/Log_vs_neglog.gif}
#
# =============================
# line ==> \includegraphics{./imgs/decisionTree.JPG}
#
# =============================
# line ==> \includegraphics{./imgs/entropy.JPG}
#
# =============================
# line ==> \includegraphics{./imgs/informationGain.JPG}
#
# =============================
# line ==>   基礎 \includegraphics{./imgs/SVM.png}
#
# =============================
# line ==> \includegraphics{./imgs/SVM_error.png}
#
# =============================
# line ==> \includegraphics{./imgs/SVM_nonLinear.png}
#
# =============================
# line ==> \includegraphics{./imgs/SVM_highdim.png}
#
# =============================
# line ==> \includegraphics{./imgs/SVM_proj.gif}
#
# =============================
# out, err
# This is XeTeX, Version 3.14159265-2.6-0.99999 (MiKTeX 2.9.6840 64-bit)
# entering extended mode
# (../05_Classification/practice05_mod.tex
# LaTeX2e <2018-04-01> patch level 5
# ("C:\Program Files\MiKTeX 2.9\tex\latex\base\article.cls"
# Document Class: article 2014/09/29 v1.4h Standard LaTeX document class
# ("C:\Program Files\MiKTeX 2.9\tex\latex\base\size11.clo"))
# ("C:\Program Files\MiKTeX 2.9\tex\latex\fontspec\fontspec.sty"
# ("C:\Program Files\MiKTeX 2.9\tex\latex\l3packages\xparse\xparse.sty"
# ("C:\Program Files\MiKTeX 2.9\tex\latex\l3kernel\expl3.sty"
# ("C:\Program Files\MiKTeX 2.9\tex\latex\l3kernel\expl3-code.tex")
# ("C:\Program Files\MiKTeX 2.9\tex\latex\l3kernel\l3xdvipdfmx.def")))
# ("C:\Program Files\MiKTeX 2.9\tex\latex\fontspec\fontspec-xetex.sty"
# ("C:\Program Files\MiKTeX 2.9\tex\latex\base\fontenc.sty"
# ("C:\Program Files\MiKTeX 2.9\tex\latex\base\tuenc.def"))
# ("C:\Program Files\MiKTeX 2.9\tex\latex\fontspec\fontspec.cfg")))
# ("C:\Program Files\MiKTeX 2.9\tex\xelatex\xecjk\xeCJK.sty"
# ("C:\Program Files\MiKTeX 2.9\tex\latex\l3packages\xtemplate\xtemplate.sty")
# ("C:\Program Files\MiKTeX 2.9\tex\latex\l3packages\l3keys2e\l3keys2e.sty")
# ("C:\Program Files\MiKTeX 2.9\tex\xelatex\xecjk\xeCJK.cfg"))
# ("C:\Program Files\MiKTeX 2.9\tex\latex\base\fontenc.sty"
# ("C:\Program Files\MiKTeX 2.9\tex\latex\base\t1enc.def")
# ("C:\Program Files\MiKTeX 2.9\tex\latex\lm\t1lmr.fd"))
# ("C:\Program Files\MiKTeX 2.9\tex\latex\psnfss\mathpazo.sty")
# ("C:\Program Files\MiKTeX 2.9\tex\latex\graphics\graphicx.sty"
# ("C:\Program Files\MiKTeX 2.9\tex\latex\graphics\keyval.sty")
# ("C:\Program Files\MiKTeX 2.9\tex\latex\graphics\graphics.sty"
# ("C:\Program Files\MiKTeX 2.9\tex\latex\graphics\trig.sty")
# ("C:\Program Files\MiKTeX 2.9\tex\latex\graphics-cfg\graphics.cfg")
# ("C:\Program Files\MiKTeX 2.9\tex\latex\graphics-def\xetex.def")))
# ("C:\Program Files\MiKTeX 2.9\tex\latex\caption\caption.sty"
# ("C:\Program Files\MiKTeX 2.9\tex\latex\caption\caption3.sty"))
# ("C:\Program Files\MiKTeX 2.9\tex\latex\adjustbox\adjustbox.sty"
# ("C:\Program Files\MiKTeX 2.9\tex\latex\xkeyval\xkeyval.sty"
# ("C:\Program Files\MiKTeX 2.9\tex\generic\xkeyval\xkeyval.tex"
# ("C:\Program Files\MiKTeX 2.9\tex\generic\xkeyval\xkvutils.tex")))
# ("C:\Program Files\MiKTeX 2.9\tex\latex\adjustbox\adjcalc.sty")
# ("C:\Program Files\MiKTeX 2.9\tex\latex\adjustbox\trimclip.sty"
# ("C:\Program Files\MiKTeX 2.9\tex\latex\collectbox\collectbox.sty")
# ("C:\Program Files\MiKTeX 2.9\tex\latex\adjustbox\tc-xetex.def"))
# ("C:\Program Files\MiKTeX 2.9\tex\latex\ifoddpage\ifoddpage.sty")
# ("C:\Program Files\MiKTeX 2.9\tex\latex\varwidth\varwidth.sty"))
# ("C:\Program Files\MiKTeX 2.9\tex\latex\xcolor\xcolor.sty"
# ("C:\Program Files\MiKTeX 2.9\tex\latex\graphics-cfg\color.cfg"))
# ("C:\Program Files\MiKTeX 2.9\tex\latex\tools\enumerate.sty")
# ("C:\Program Files\MiKTeX 2.9\tex\latex\geometry\geometry.sty"
# ("C:\Program Files\MiKTeX 2.9\tex\generic\oberdiek\ifpdf.sty")
# ("C:\Program Files\MiKTeX 2.9\tex\generic\oberdiek\ifvtex.sty")
# ("C:\Program Files\MiKTeX 2.9\tex\generic\ifxetex\ifxetex.sty")
# ("C:\Program Files\MiKTeX 2.9\tex\xelatex\xetexconfig\geometry.cfg"))
# ("C:\Program Files\MiKTeX 2.9\tex\latex\amsmath\amsmath.sty"
# For additional information on amsmath, use the `?' option.
# ("C:\Program Files\MiKTeX 2.9\tex\latex\amsmath\amstext.sty"
# ("C:\Program Files\MiKTeX 2.9\tex\latex\amsmath\amsgen.sty"))
# ("C:\Program Files\MiKTeX 2.9\tex\latex\amsmath\amsbsy.sty")
# ("C:\Program Files\MiKTeX 2.9\tex\latex\amsmath\amsopn.sty"))
# ("C:\Program Files\MiKTeX 2.9\tex\latex\amsfonts\amssymb.sty"
# ("C:\Program Files\MiKTeX 2.9\tex\latex\amsfonts\amsfonts.sty"))
# ("C:\Program Files\MiKTeX 2.9\tex\latex\base\textcomp.sty"
# ("C:\Program Files\MiKTeX 2.9\tex\latex\base\ts1enc.def"))
# ("C:\Program Files\MiKTeX 2.9\tex\latex\upquote\upquote.sty")
# ("C:\Program Files\MiKTeX 2.9\tex\latex\eurosym\eurosym.sty")
# ("C:\Program Files\MiKTeX 2.9\tex\latex\ucs\ucs.sty"
# ("C:\Program Files\MiKTeX 2.9\tex\latex\ucs\uni-global.def"))
# ("C:\Program Files\MiKTeX 2.9\tex\latex\base\inputenc.sty"
#
# Package inputenc Warning: inputenc package ignored with utf8 based engines.
#
# ) ("C:\Program Files\MiKTeX 2.9\tex\latex\fancyvrb\fancyvrb.sty"
# Style option: `fancyvrb' v2.7a, with DG/SPQR fixes, and firstline=lastline fix
# <2008/02/07> (tvz)) ("C:\Program Files\MiKTeX 2.9\tex\latex\oberdiek\grffile.st
# y" ("C:\Program Files\MiKTeX 2.9\tex\latex\oberdiek\kvoptions.sty"
# ("C:\Program Files\MiKTeX 2.9\tex\generic\oberdiek\ltxcmds.sty")
# ("C:\Program Files\MiKTeX 2.9\tex\generic\oberdiek\kvsetkeys.sty"
# ("C:\Program Files\MiKTeX 2.9\tex\generic\oberdiek\infwarerr.sty")
# ("C:\Program Files\MiKTeX 2.9\tex\generic\oberdiek\etexcmds.sty"
# ("C:\Program Files\MiKTeX 2.9\tex\generic\oberdiek\ifluatex.sty"))))
# ("C:\Program Files\MiKTeX 2.9\tex\generic\oberdiek\pdftexcmds.sty"))
# ("C:\Program Files\MiKTeX 2.9\tex\latex\hyperref\hyperref.sty"
# ("C:\Program Files\MiKTeX 2.9\tex\generic\oberdiek\hobsub-hyperref.sty"
# ("C:\Program Files\MiKTeX 2.9\tex\generic\oberdiek\hobsub-generic.sty"))
# ("C:\Program Files\MiKTeX 2.9\tex\latex\oberdiek\auxhook.sty")
# ("C:\Program Files\MiKTeX 2.9\tex\latex\hyperref\pd1enc.def")
# ("C:\Program Files\MiKTeX 2.9\tex\latex\00miktex\hyperref.cfg")
# ("C:\Program Files\MiKTeX 2.9\tex\latex\url\url.sty"))
# ("C:\Program Files\MiKTeX 2.9\tex\latex\hyperref\hxetex.def"
# ("C:\Program Files\MiKTeX 2.9\tex\latex\hyperref\puenc.def")
# ("C:\Program Files\MiKTeX 2.9\tex\generic\oberdiek\stringenc.sty")
# ("C:\Program Files\MiKTeX 2.9\tex\latex\oberdiek\rerunfilecheck.sty"))
# ("C:\Program Files\MiKTeX 2.9\tex\latex\tools\longtable.sty")
# ("C:\Program Files\MiKTeX 2.9\tex\latex\booktabs\booktabs.sty")
# ("C:\Program Files\MiKTeX 2.9\tex\latex\enumitem\enumitem.sty")
# ("C:\Program Files\MiKTeX 2.9\tex\latex\ulem\ulem.sty")
# ("C:\Program Files\MiKTeX 2.9\tex\latex\jknappen\mathrsfs.sty")
# ("C:\Program Files\MiKTeX 2.9\tex\xelatex\xecjk\xeCJKfntef.sty"
# ("C:\Program Files\MiKTeX 2.9\tex\latex\environ\environ.sty"
# ("C:\Program Files\MiKTeX 2.9\tex\latex\trimspaces\trimspaces.sty"))
# ("C:\Program Files\MiKTeX 2.9\tex\latex\cjk\CJKfntef.sty")) (practice05_mod.aux
#
#
# LaTeX Warning: Label `ux7406ux8ad6' multiply defined.
#
#
# LaTeX Warning: Label `ux7406ux8ad6' multiply defined.
#
#
# LaTeX Warning: Label `ux7406ux8ad6' multiply defined.
#
# ) ("C:\Program Files\MiKTeX 2.9\tex\latex\base\ts1cmr.fd")
# ("C:\Program Files\MiKTeX 2.9\tex\latex\psnfss\t1ppl.fd")
# ("C:\Program Files\MiKTeX 2.9\tex\latex\caption\ltcaption.sty")
# *geometry* detected driver: pdftex
# *geometry* verbose mode - [ preamble ] result:
# * driver: pdftex
# * paper: <default>
# * layout: <same size as paper>
# * layoutoffset:(h,v)=(0.0pt,0.0pt)
# * modes:
# * h-part:(L,W,R)=(72.26999pt, 469.75502pt, 72.26999pt)
# * v-part:(T,H,B)=(72.26999pt, 650.43001pt, 72.26999pt)
# * \paperwidth=614.295pt
# * \paperheight=794.96999pt
# * \textwidth=469.75502pt
# * \textheight=650.43001pt
# * \oddsidemargin=0.0pt
# * \evensidemargin=0.0pt
# * \topmargin=-37.0pt
# * \headheight=12.0pt
# * \headsep=25.0pt
# * \topskip=11.0pt
# * \footskip=30.0pt
# * \marginparwidth=59.0pt
# * \marginparsep=10.0pt
# * \columnsep=10.0pt
# * \skip\footins=10.0pt plus 4.0pt minus 2.0pt
# * \hoffset=0.0pt
# * \voffset=0.0pt
# * \mag=1000
# * \@twocolumnfalse
# * \@twosidefalse
# * \@mparswitchfalse
# * \@reversemarginfalse
# * (1in=72.27pt=25.4mm, 1cm=28.453pt)
#
# ("C:\Program Files\MiKTeX 2.9\tex\latex\ucs\ucsencs.def")
# ("C:\Program Files\MiKTeX 2.9\tex\latex\hyperref\nameref.sty"
# ("C:\Program Files\MiKTeX 2.9\tex\generic\oberdiek\gettitlestring.sty"))
# (practice05_mod.out) (practice05_mod.out)
# ("C:\Program Files\MiKTeX 2.9\tex\latex\psnfss\ot1ppl.fd")
# ("C:\Program Files\MiKTeX 2.9\tex\latex\psnfss\omlzplm.fd")
# ("C:\Program Files\MiKTeX 2.9\tex\latex\psnfss\omszplm.fd")
# ("C:\Program Files\MiKTeX 2.9\tex\latex\psnfss\omxzplm.fd")
# ("C:\Program Files\MiKTeX 2.9\tex\latex\psnfss\ot1zplm.fd")
# ("C:\Program Files\MiKTeX 2.9\tex\latex\jknappen\ursfs.fd")
#
# LaTeX Warning: No \author given.
#
# ("C:\Program Files\MiKTeX 2.9\tex\generic\oberdiek\se-ascii-print.def")
# ("C:\Program Files\MiKTeX 2.9\tex\latex\psnfss\ts1ppl.fd")
# Overfull \hbox (7.39166pt too wide) in paragraph at lines 339--341
# []|\T1/ppl/m/n/10.95 qid1|
#
# Overfull \hbox (7.39166pt too wide) in paragraph at lines 341--343
# []|\T1/ppl/m/n/10.95 qid2|
#
# Overfull \hbox (30.51788pt too wide) in paragraph at lines 347--349
# []|\T1/ppl/m/n/10.95 is_duplicate|
# [1]
#
# Package xeCJK Warning: Unknown CJK family `\CJKttdefault' is being ignored.
# (xeCJK)
# (xeCJK)                Try to use `\setCJKmonofont[...]{...}' to define it.
#
# ("C:\Program Files\MiKTeX 2.9\tex\latex\lm\t1lmtt.fd") [2]
# ("C:\Program Files\MiKTeX 2.9\tex\latex\lm\ts1lmtt.fd") [3]
# Underfull \hbox (badness 10000) in paragraph at lines 521--522
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 526--527
#
# [4] [5]
#
# LaTeX Font Warning: Font shape `TU/微軟正黑體(0)/m/it' undefined
# (Font)              using `TU/微軟正黑體(0)/m/n' instead on input line 604.
#
# [6]
# Underfull \hbox (badness 10000) in paragraph at lines 622--623
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 632--633
#
# [7] [8] [9] [10] [11]
# Underfull \hbox (badness 10000) in paragraph at lines 892--893
#
# [12]
# Underfull \hbox (badness 10000) in paragraph at lines 902--903
#
# [13] [14] [15] [16]
# Underfull \hbox (badness 10000) in paragraph at lines 1111--1112
#
# [17]
# Underfull \hbox (badness 10000) in paragraph at lines 1126--1127
#
# [18] [19] [20] [21] [22] [23] [24] [25] [26]
# Underfull \hbox (badness 10000) in paragraph at lines 1561--1562
#
# [27]
# Underfull \hbox (badness 10000) in paragraph at lines 1576--1577
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 1586--1587
#
# [28]
# Underfull \hbox (badness 10000) in paragraph at lines 1596--1597
#
# [29]
# Underfull \hbox (badness 10000) in paragraph at lines 1606--1607
#
# [30]
# Underfull \hbox (badness 10000) in paragraph at lines 1621--1622
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 1631--1632
#
# [31]
# Underfull \hbox (badness 10000) in paragraph at lines 1641--1642
#
# [32] [33] [34] [35] [36]
# Underfull \hbox (badness 10000) in paragraph at lines 1835--1836
#
# [37]
# Underfull \hbox (badness 10000) in paragraph at lines 1850--1851
#
# [38]
# Underfull \hbox (badness 10000) in paragraph at lines 1865--1866
#
# [39]
# Underfull \hbox (badness 10000) in paragraph at lines 1880--1881
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 1890--1891
#
# [40]
# Underfull \hbox (badness 10000) in paragraph at lines 1905--1906
#
# [41]
# Underfull \hbox (badness 10000) in paragraph at lines 1920--1921
#
# [42]
# Underfull \hbox (badness 10000) in paragraph at lines 1935--1936
#
# [43] [44] (practice05_mod.aux)
#
# LaTeX Font Warning: Some font shapes were not available, defaults substituted.
#
#
# LaTeX Warning: There were multiply-defined labels.
#
#  )
# (see the transcript file for additional information)
# Output written on practice05_mod.pdf (44 pages).
# Transcript written on practice05_mod.log.
#
# =================
# =================
# =================
# =================
# =================

# %%
# [os.remove(f) for f in os.listdir() if f.startswith(filename.replace('.ipynb', ''))]
# Out:
# [None, None, None, None]
