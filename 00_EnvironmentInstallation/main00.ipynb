# %% [markdown]
# # 環境設定檢查方式

# %% [markdown]
# 1. 打開命令提示字元
#     1. git
#     ```
#     >>> git
#     usage: git [--version] [--help] [-C <path>] [-c name=value]
#                [--exec-path[=<path>]] [--html-path] [--man-path] [--info-path]
#                [-p | --paginate | --no-pager] [--no-replace-objects] [--bare]
#                [--git-dir=<path>] [--work-tree=<path>] [--namespace=<name>]
#                <command> [<args>]
#     ......
#     ```
#
#     2. python(注意python版本必須是3.5 or 3.6)
#     ```
#     >>> python -V
#     Python 3.6.X
#     ```
#
#     3. pip(注意最後面對應的python版本即可)
#     ```
#     >>> pip -V
#     pip 10.0.1 from C:\Users\<UserName>\AppData\Local\Programs\Python\Python35\lib\site-packages\pip (python 3.6)
#     ```
#
#     4. jupyter(有數字跑出來即可)
#     ```
#     >>> jupyter --version
#     x.x.x
#     ```
#
# 2. 如果有尚未安裝完成的軟體，請按照以下步驟安裝，務必詳細按照步驟安裝。

# %% [markdown]
# # Instruction
# Before you start to take this class, you should install three software: git, python3.6 (and its packages listed below) and jupyter. Pleas first checking if you have installed these software with right version. Please open command line (terminal) follow the following instruction to verfify them.
#
# 1. git
#     ```
#     >>>git
#     usage: git [--version] [--help] [-C <path>] [-c <name>=<value>]
#            [--exec-path[=<path>]] [--html-path] [--man-path] [--info-path]
#            [-p | --paginate | -P | --no-pager] [--no-replace-objects] [--bare]
#            [--git-dir=<path>] [--work-tree=<path>] [--namespace=<name>]
#            <command> [<args>]
#     .........
#     ```
#
# 2. python3.6 (please ensure your python version is 3.6)
#     ```
#     >>>python -V
#     Python 3.6.X
#     >>> pip -V
#     pip 9.0.1 from C:\.......\pip (python 3.6)
#     ```
#
# 3. jupyter
#     ```
#     >>>jupyter --version
#     jupyter core     : 4.5.0
#     jupyter-notebook : 5.7.8
#     qtconsole        : 4.5.1
#     ipython          : 7.5.0
#     ipykernel        : 5.1.1
#     jupyter client   : 5.2.4
#     jupyter lab      : not installed
#     nbconvert        : 5.5.0
#     ipywidgets       : 7.4.2
#     nbformat         : 4.4.0
#     traitlets        : 4.3.2
#     ```
#
# 4. depency
#     ```
#     >>> pip list
#     Package            Version
#     ------------------ ----------
#     backcall           0.1.0
#     beautifulsoup4     4.6.3
#     bleach             3.0.2
#     boto3              1.9.33
#     botocore           1.12.33
#     bs4          "      0.0.1
#     certifi            2018.10.15
#     chardet            3.0.4
#     colorama           0.4.0
#     cycler             0.10.0
#     decorator          4.3.0
#     defusedxml         0.5.0
#     docutils           0.14
#     entrypoints        0.2.3
#     idna               2.7
#     ipykernel          5.1.0
#     ipython            7.0.1
#     ipython-genutils   0.2.0
#     ipywidgets         7.4.2
#     jedi               0.13.1
#     jieba              0.39
#     Jinja2             2.10
#     jmespath           0.9.3
#     jsonschema         2.6.0
#     jupyter-client     5.2.3
#     jupyter-console    6.0.0
#     jupyter-core       4.4.0
#     kiwisolver         1.0.1
#     MarkupSafe         1.0
#     matplotlib         3.0.0
#     mistune            0.8.4
#     nbconvert          5.4.0
#     nbformat           4.4.0
#     nltk               3.3
#     notebook           5.7.0
#     numpy              1.15.3
#     pandas             0.23.4
#     pandocfilters      1.4.2
#     parso              0.3.1
#     pickleshare        0.7.5
#     Pillow             5.4.1
#     pip                19.2.2
#     prometheus-client  0.4.2
#     prompt-toolkit     2.0.6
#     Pygments           2.2.0
#     pyparsing          2.2.2
#     python-dateutil    2.7.3
#     pytz               2018.5
#     pywinpty           0.5.4
#     pyzmq              17.1.2
#     qtconsole          4.4.2
#     requests           2.19.1
#     s3transfer         0.1.13
#     scikit-learn       0.20.0
#     scipy              1.1.0
#     Send2Trash         1.5.0
#     setuptools         41.2.0
#     simplegeneric      0.8.1
#     six                1.11.0
#     sklearn            0.0
#     terminado          0.8.1
#     testpath           0.4.2
#     tornado            5.1.1
#     traitlets          4.3.2
#     urllib3            1.23
#     wcwidth            0.1.7
#     webencodings       0.5.1
#     wheel              0.33.6
#     widgetsnbextension 3.4.2
#     wordcloud          1.5.0
#     xgboost            0.80
#     ```

# %% [markdown]
# # Installation
# ## Git
# 1. install
#     1. go to [official site](https://git-scm.com/download/win)
#     2. download executable
#     3. open executabled: Always "Next"
# 2. testing
#     1. open Command line (命令提示字元)
#         ```
#         >>>git
#         usage: git [--version] [--help] [-C <path>] [-c <name>=<value>]
#                [--exec-path[=<path>]] [--html-path] [--man-path] [--info-path]
#                [-p | --paginate | -P | --no-pager] [--no-replace-objects] [--bare]
#                [--git-dir=<path>] [--work-tree=<path>] [--namespace=<name>]
#                <command> [<args>]
#         .........
#         ```
# 3. download git repo
#     ```
#     git clone https://github.com/GoatWang/IIIMaterial
#     ```
#
# ## Python(Don't use conda or VS please)
# 1. intall
#     1. go to [python 3.6.4 download page](https://www.python.org/downloads/release/python-364/)(official site)
#
#     ![download](./imgs/Download364.PNG)
#
#     2. Download "Windows x86-64 executable installer"
#     3. Open installer
#         1. (very important!!) check "Add Python 3.6 to PATH" at bottom
#
#         ![download](./imgs/installation.PNG)
#
#         2. click install now
# 2. testing:
#     1. open Command line (命令提示字元)
#         ```
#         >>>python -V
#         Python 3.6.4
#         >>>pip -V
#         pip 9.0.1 from C:\.......\pip (python 3.6)
#         ```
#
# ## Jupyter
# 1. install:
#     1. open Command line (命令提示字元) with admin auth (以管理員權限開啟)
#         ```
#         >>>pip install --upgrade pip
#         >>>pip install jupyter
#         ```
# 2. testing
#     1. open Command line (命令提示字元)
#         ```
#         >>>jupyter notebook
#         ```
#
# ## Dependency(Don't use conda or VS please)
# 1. install
#     1. option 1: install your self
#         ```
#         >>>pip install numpy pandas scikit-learn matplotlib requests xgboost bs4
#         ```
#     2. option 2: install through requirements.txt
#         ```
#         >>>pip install -r requirements.txt
#         ```
# 2. testing
#
#     1. open Command line (命令提示字元)
#         ```
#         >>> pip list
#         Package            Version
#         ------------------ ----------
#         backcall           0.1.0
#         beautifulsoup4     4.6.3
#         bleach             3.0.2
#         boto3              1.9.33
#         botocore           1.12.33
#         bs4                0.0.1
#         certifi            2018.10.15
#         chardet            3.0.4
#         colorama           0.4.0
#         cycler             0.10.0
#         decorator          4.3.0
#         defusedxml         0.5.0
#         docutils           0.14
#         entrypoints        0.2.3
#         idna               2.7
#         ipykernel          5.1.0
#         ipython            7.0.1
#         ipython-genutils   0.2.0
#         ipywidgets         7.4.2
#         jedi               0.13.1
#         jieba              0.39
#         Jinja2             2.10
#         jmespath           0.9.3
#         jsonschema         2.6.0
#         jupyter-client     5.2.3
#         jupyter-console    6.0.0
#         jupyter-core       4.4.0
#         kiwisolver         1.0.1
#         MarkupSafe         1.0
#         matplotlib         3.0.0
#         mistune            0.8.4
#         nbconvert          5.4.0
#         nbformat           4.4.0
#         nltk               3.3
#         notebook           5.7.0
#         numpy              1.15.3
#         pandas             0.23.4
#         pandocfilters      1.4.2
#         parso              0.3.1
#         pickleshare        0.7.5
#         Pillow             5.4.1
#         pip                19.2.2
#         prometheus-client  0.4.2
#         prompt-toolkit     2.0.6
#         Pygments           2.2.0
#         pyparsing          2.2.2
#         python-dateutil    2.7.3
#         pytz               2018.5
#         pywinpty           0.5.4
#         pyzmq              17.1.2
#         qtconsole          4.4.2
#         requests           2.19.1
#         s3transfer         0.1.13
#         scikit-learn       0.20.0
#         scipy              1.1.0
#         Send2Trash         1.5.0
#         setuptools         41.2.0
#         simplegeneric      0.8.1
#         six                1.11.0
#         sklearn            0.0
#         terminado          0.8.1
#         testpath           0.4.2
#         tornado            5.1.1
#         traitlets          4.3.2
#         urllib3            1.23
#         wcwidth            0.1.7
#         webencodings       0.5.1
#         wheel              0.33.6
#         widgetsnbextension 3.4.2
#         wordcloud          1.5.0
#         xgboost            0.80
#         ```

# %% [markdown]
# # Jupyter 快捷鍵
# If you have time you can try to use jupyter to write code
# 0. shift-enter: 跑程式
# 1. A: 上面增加一格
# 2. B: 下面增加一格
# 3. C: 複製
# 4. V: 貼上
# 5. Z: 復原
# 6. shift-up & shift-down: 多個block選取
# 7. M: markdown抄筆記
# 8. shift + tab: param instruction
# 9. tab: functions instruction
